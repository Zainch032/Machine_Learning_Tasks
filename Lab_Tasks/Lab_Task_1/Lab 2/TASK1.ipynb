# %% [markdown]
# #### Activity 1:

# %%
lists = []
for i in range(5):
    n = input("Enter a value :")
    lists.append(n)
    
print(lists)
# Out:
# ['23', '2', '5', '1', '9']

# %% [markdown]
# #### Activity 2 :

# %%
mylist = []
for i in range(5):
    n = input("Enter a number: ")
    s = int(n)
    print(f"You entered the value {s}")
    mylist.append(s)
    
mylist.sort()
print(mylist)
# Out:
# You entered the value 2
# You entered the value 0
# You entered the value -1
# You entered the value 22
# You entered the value 10
# [-1, 0, 2, 10, 22]

# %% [markdown]
# #### Activity 3 :

# %%
list1 = []
list2 = []

for i in range(5):
    val1 = input("Enter value for list 1 :")
    print(f"You entered value for list 1 :{val1}")
    list1.append(val1)
 
for z in range(5):
    val2 = input("Enter value for list 2 :")
    print(f"You entered value for list 2 :{val2}")
    list2.append(val2)
    
list3 = list1 + list2
print(list3)
# Out:
# You entered value for list 1 :1
# You entered value for list 1 :3
# You entered value for list 1 :2
# You entered value for list 1 :0
# You entered value for list 1 :1
# You entered value for list 2 :-2
# You entered value for list 2 :1
# You entered value for list 2 :5
# You entered value for list 2 :3
# You entered value for list 2 :8
# ['1', '3', '2', '0', '1', '-2', '1', '5', '3', '8']

# %% [markdown]
# #### Activity 4 :

# %%
list = ["Hey", "whatsup",4]
print("\nList containing multiple values:")
print(list)

list2 =[['Geeks','For'],['Geeks']]
print("\nList containing multiple values:")
print(list2)

print("Accessing elements of a list:")
print("First element of the list: ", list[0])
print("last element of the list: ", list[-1])
print(list[-3])
# Out:
# List containing multiple values:
# ['Hey', 'whatsup', 4]
#
# List containing multiple values:
# [['Geeks', 'For'], ['Geeks']]
# Accessing elements of a list:
# First element of the list:  Hey
# last element of the list:  4
# Hey

# %% [markdown]
# #### Activity 5:
#
# * Dictionary

# %%
dict = {'Name' : 'Geeks' , 1 :[1,2,3,4]}
print("Create Dictionary :")
print(dict)

print("Accessing a element using key :")
print("dict['Name'] : ", dict['Name'])

print("Accesing element using get :")
print("dict.get(1) : ", dict.get(1))

myDict = {x : x**2 for x in [1, 2, 3, 4]}
print(myDict)
# Out:
# Create Dictionary :
# {'Name': 'Geeks', 1: [1, 2, 3, 4]}
# Accessing a element using key :
# dict['Name'] :  Geeks
# Accesing element using get :
# dict.get(1) :  [1, 2, 3, 4]
# {1: 1, 2: 4, 3: 9, 4: 16}

# %%
from collections import OrderedDict

od = OrderedDict()
od['a'] = 1
od['b'] = 2
od['c'] = 3
od['d'] = 4

for key,value in od.items():
    print(key,"--->",value)
 
print("\nAfter deleting:\n") 
od.pop('c') 
for key, value in od.items(): 
  print(key,"--->", value) 
 
print("\nAfter re-inserting:\n") 
od['c'] = 3 
for key, value in od.items(): 
   print(key,"--->", value)
# Out:
# a ---> 1
# b ---> 2
# c ---> 3
# d ---> 4
#
# After deleting:
#
# a ---> 1
# b ---> 2
# d ---> 4
#
# After re-inserting:
#
# a ---> 1
# b ---> 2
# d ---> 4
# c ---> 3

# %%
from collections import ChainMap 
 
d1 = {'a': 1, 'b': 2} 
d2 = {'c': 3, 'd': 4} 
d3 = {'e': 5, 'f': 6} 
 
# Defining the chainmap 
c = ChainMap(d1, d2, d3) 
print(c) 
 
print(c['a']) 
print(c['g'])
# Out:
# ChainMap({'a': 1, 'b': 2}, {'c': 3, 'd': 4}, {'e': 5, 'f': 6})
# 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 12
#       9 print(c)
#      11 print(c['a'])
# ---> 12 print(c['g'])
#
# File c:\Users\Zainch-032\AppData\Local\Programs\Python\Python311\Lib\collections\__init__.py:1004, in ChainMap.__getitem__(self, key)
#    1002     except KeyError:
#    1003         pass
# -> 1004 return self.__missing__(key)
#
# File c:\Users\Zainch-032\AppData\Local\Programs\Python\Python311\Lib\collections\__init__.py:996, in ChainMap.__missing__(self, key)
#     995 def __missing__(self, key):
# --> 996     raise KeyError(key)
#
# KeyError: 'g'

# %% [markdown]
# #### Activity 6 :
#
# * Tuple

# %%
Tuple = ('Geeks', 'For') 
print("\nTuple with the use of String: ") 
print(Tuple) 
 
list1 = [1, 2, 4, 5, 6] 
print("\nTuple using List: ") 
Tuple = tuple(list1) 

print(Tuple)
print("First element of tuple") 
print(Tuple[0]) 
 
print("\nLast element of tuple") 
print(Tuple[-1]) 
 
print("\nThird last element of tuple") 
print(Tuple[-3])
# Out:
# Tuple with the use of String:
# ('Geeks', 'For')
#
# Tuple using List:
# (1, 2, 4, 5, 6)
# First element of tuple
# 1
#
# Last element of tuple
# 6
#
# Third last element of tuple
# 4

# %%
from collections import namedtuple 

Student = namedtuple('Student',['name','age','DOB']) 

S = Student('Akber','19','2541997') 

print ("The Student age using index is : ",end ="") 
print (S[1]) 

print ("The Student name using keyname is : ",end ="") 
print (S.name)
# Out:
# The Student age using index is : 19
# The Student name using keyname is : Akber

# %% [markdown]
# * Set

# %%
Set = set([1, 2, 'Geeks', 4, 'For', 6, 'Geeks']) 
print("\nSet with the use of Mixed Values") 
print(Set) 
 

print("\nElements of set: ") 
for i in Set: 
  print(i, end =" ") 
print() 
 
# Checking the element 
# using in keyword 
print("Geeks" in Set)
# Out:
# Set with the use of Mixed Values
# {1, 2, 'For', 4, 6, 'Geeks'}
#
# Elements of set:
# 1 2 For 4 6 Geeks
# True

# %% [markdown]
# * Strings

# %%
 
String = "Welcome to GeeksForGeeks" 
print("Creating String: ") 
print(String) 
 

print("\nFirst character of String is: ") 
print(String[0]) 
  
print("\nLast character of String is: ") 
print(String[-1])
# Out:
# Creating String:
# Welcome to GeeksForGeeks
#
# First character of String is:
# W
#
# Last character of String is:
# s

# %% [markdown]
# #### Activity 9

# %%
 
class Person: 
   def  __init__(self, name, age): 
       self.name = name 
       self.age = age
   def myfunc(self): 
        print("Hello my name is " + self.name) 
p1 = Person("akber", 36) 
p1.myfunc()
# Out:
# Hello my name is akber

# %% [markdown]
# ### Activity 10

# %%
import tracemalloc

def app(): 
    lt = [] 
    for i in range(0, 100000): 
        lt.append(i) 

# Start monitoring memory
tracemalloc.start()

# Call the function
app()

# Get memory usage
print(tracemalloc.get_traced_memory())

# Stop monitoring
tracemalloc.stop()
# Out:
# (930, 3993615)
